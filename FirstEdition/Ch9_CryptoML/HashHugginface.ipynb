# %%
from Crypto.Hash import MD5

# %%
## !pip install pycryptodome
## !pip install transformers

# %%
## wget https://nlp.stanford.edu/projects/snli/snli_1.0.zip

# %%
m = MD5.new()

string_value = b'buy the stock at $2500 a share'

m.update( string_value )

print( m.digest()     )
print( m.hexdigest()  )
# Out:
# b'E\x0c\xde\xc3B\xff\xb9\x16\x877\xcc\xab\x03)\x08d'
# 450cdec342ffb9168737ccab03290864

# %%
def hash_fn( token ):
    m = MD5.new()
    m.update( token )
    return m.hexdigest()

# %%
passwords = ["egg", "school", "house", "horse"]

for word in passwords:
    res = hash_fn( word.encode() )
    print( word, "," ,res )
# Out:
# egg , 0e9312087f58f367d001ec9bae8f325a
# school , 7516c3b35580b3490248629cff5e498c
# house , 2ca63cddd54f9490efad22421891a9d1
# horse , f1bdf5ed1d7ad7ede4e3809bd35644b0

# %%
import hashlib
from transformers import AutoTokenizer

# Choose a tokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

def text_to_hash(text):
    # Tokenize the text
    encoded_text = tokenizer(text, return_tensors="pt")

    # Convert the tokenized text to a string
    token_string = str(encoded_text)

    # Create a hash object
    hash_object = hashlib.sha256(token_string.encode())

    # Get the hexadecimal representation of the hash
    hex_dig = hash_object.hexdigest()

    return hex_dig

# Example usage
text = "This is an example text to be hashed."
hash_value = text_to_hash(text)
print(hash_value)
# Out:
# ce74fbefa39f73839ee80dee6888d795553dd05196e714dcb35c90a7f4be2620

# %%
from transformers import pipeline

classifier = pipeline("token-classification", model = "vblagoje/bert-english-uncased-finetuned-pos")
classifier("Hello I'm Omar and I live in Zürich.")
# Out:
# Some weights of the model checkpoint at vblagoje/bert-english-uncased-finetuned-pos were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'entity': 'INTJ',
#   'score': 0.99677867,
#   'index': 1,
#   'word': 'hello',
#   'start': 0,
#   'end': 5},
#  {'entity': 'PRON',
# ...

# %%
classifier = pipeline("token-classification", model = "vblagoje/bert-english-uncased-finetuned-pos")

classifier(hash_value)
# Out:
# Some weights of the model checkpoint at vblagoje/bert-english-uncased-finetuned-pos were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'entity': 'NOUN',
#   'score': 0.9588896,
#   'index': 1,
#   'word': 'ce',
#   'start': 0,
#   'end': 2},
#  {'entity': 'NUM',
#   'score': 0.9532486,
# ...
